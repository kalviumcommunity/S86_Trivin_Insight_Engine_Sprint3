# %% [markdown]
# # Jupyter Notebook Basics - Milestone Verification
#
# This notebook demonstrates understanding of:
# - Jupyter Notebook launching and interface
# - Folder navigation and file management
# - Creating and executing notebook cells
# - Basic Python execution in Jupyter
#
# **Date Created:** February 25, 2026

# %% [markdown]
# ## 1. Environment Verification
#
# First, let's verify that Jupyter is running correctly and check our Python environment.

# %%
# Verify Jupyter is working
print("✅ Jupyter Notebook is running correctly!")
print(f"Notebook created in the correct project folder")

# %%
# Check Python version and basic imports
import sys
import os

print(f"Python Version: {sys.version}")
print(f"\nCurrent Working Directory:")
print(os.getcwd())

# %% [markdown]
# ## 2. Basic Python Operations
#
# Demonstrating that the kernel is active and can execute code properly.

# %%
# Basic calculations
result = 10 + 20 * 2
print(f"Mathematical operation result: {result}")

# List operations
data = [1, 2, 3, 4, 5]
print(f"\nList sum: {sum(data)}")
print(f"List average: {sum(data) / len(data)}")

# %% [markdown]
# ## 3. Data Science Libraries Check
#
# Verifying that common data science libraries are accessible.

# %%
# Import common data science libraries
try:
    import numpy as np
    print("✅ NumPy imported successfully")
except ImportError:
    print("❌ NumPy not available")

try:
    import pandas as pd
    print("✅ Pandas imported successfully")
except ImportError:
    print("❌ Pandas not available")

try:
    import matplotlib.pyplot as plt
    print("✅ Matplotlib imported successfully")
except ImportError:
    print("❌ Matplotlib not available")
# Out:
# ✅ NumPy imported successfully
# ✅ Pandas imported successfully
# ✅ Matplotlib imported successfully
