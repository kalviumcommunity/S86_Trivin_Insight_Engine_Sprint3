# %% [markdown]
# # Visualizing Data Distributions Using Histograms
#
# **Milestone: Histogram Visualization for Exploratory Data Analysis**
# **Project: Trivin Insight Engine**
# **Date: March 2026**
#
# ---
#
# ## Learning Objectives
#
# By completing this notebook, you will be able to:
#
# 1. ✅ Understand what a histogram represents
# 2. ✅ Visualize the distribution of numeric data
# 3. ✅ Interpret frequency, range, and spread
# 4. ✅ Identify skewness and unusual patterns
# 5. ✅ Use histograms as part of exploratory data analysis (EDA)
#
# ---
#
# ## Why This Matters
#
# **Visualization helps you see the data, not just describe it numerically.**
#
# Common beginner issues include:
#
# - Relying only on averages without seeing the data
# - Missing skewed or multi-modal distributions
# - Overlooking outliers that affect analysis
# - Misinterpreting summary statistics
#
# Histograms reveal patterns that numbers alone cannot.
#
# ---
#
# ## What You Will Do
#
# This is a **data visualization milestone**, not a modeling task.
#
# You will:
#
# 1. Load a dataset into a DataFrame
# 2. Select one or more numeric columns
# 3. Create histograms for those columns
# 4. Interpret what the histograms show
#
# No modeling or advanced visualization is required.
#
# ---

# %% [markdown]
# ## Setup: Import Libraries and Load Data

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# Configure display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# Configure matplotlib for better default appearance
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11

print("Libraries imported successfully")

# %%
# Load the employee survey dataset
project_root = Path.cwd().resolve().parent
csv_path = project_root / "data" / "processed" / "employee_survey_cleaned_2026_Q1.csv"

df = pd.read_csv(csv_path)

print(f"Dataset loaded from: {csv_path}")
print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")
print("\nFirst few rows:")
df.head()

# %% [markdown]
# ---
#
# ## Part 1: Understanding Histograms
#
# ### What is a Histogram?
#
# A **histogram** is a visual representation of the distribution of numeric data.
#
# Key concepts:
#
# - **Bins**: Ranges that group values together (e.g., 0-1, 1-2, 2-3)
# - **Frequency**: How many values fall into each bin
# - **Distribution Shape**: The overall pattern of the data
#
# ### Histogram vs. Bar Chart
#
# - **Histogram**: Shows distribution of **continuous numeric** data
# - **Bar Chart**: Shows counts or comparisons of **categorical** data
#
# ### What Histograms Reveal
#
# 1. **Central tendency**: Where most values cluster
# 2. **Spread**: How wide the distribution is
# 3. **Shape**: Normal, skewed, uniform, multi-modal
# 4. **Outliers**: Unusual values far from the rest
#
# ---

# %% [markdown]
# ## Part 2: Creating a Histogram for a Single Column
#
# Let's visualize the distribution of **satisfaction_score**.
#
# This shows how employee satisfaction is distributed across the survey.

# %%
# Check the column and its basic statistics
print("Satisfaction Score Statistics:")
print(df['satisfaction_score'].describe())
print(f"\nData type: {df['satisfaction_score'].dtype}")

# %%
# Create a histogram for satisfaction_score
plt.figure(figsize=(10, 6))

plt.hist(df['satisfaction_score'], bins=10, color='steelblue', edgecolor='black', alpha=0.7)

plt.xlabel('Satisfaction Score', fontsize=12, fontweight='bold')
plt.ylabel('Frequency (Number of Employees)', fontsize=12, fontweight='bold')
plt.title('Distribution of Employee Satisfaction Scores', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print("\n✅ Histogram created successfully")

# %% [markdown]
# ### Interpretation Questions
#
# Look at the histogram above and answer:
#
# 1. **Where are most values located?** (low, middle, or high scores)
# 2. **Is the distribution symmetric or skewed?**
# 3. **Are there any gaps or unusual patterns?**
# 4. **Do you see any potential outliers?**
#
# ---

# %% [markdown]
# ## Part 3: Interpreting Distribution Shape
#
# ### Common Distribution Shapes
#
# 1. **Normal (Bell-Shaped)**: Symmetric, most values in the middle
# 2. **Right-Skewed (Positive Skew)**: Long tail on the right, most values on the left
# 3. **Left-Skewed (Negative Skew)**: Long tail on the left, most values on the right
# 4. **Uniform**: Values spread evenly across the range
# 5. **Bimodal**: Two distinct peaks
#
# ### Let's Check Multiple Columns
#
# We'll create histograms for several survey metrics to practice shape identification.

# %%
# Select numeric columns for visualization
numeric_columns = [
    'satisfaction_score',
    'work_life_balance',
    'management_support',
    'career_growth',
    'team_collaboration'
]

print("Columns selected for histogram visualization:")
for col in numeric_columns:
    print(f"  - {col}")

# %%
# Create histograms for work_life_balance
plt.figure(figsize=(10, 6))

plt.hist(df['work_life_balance'], bins=10, color='seagreen', edgecolor='black', alpha=0.7)

plt.xlabel('Work-Life Balance Score', fontsize=12, fontweight='bold')
plt.ylabel('Frequency', fontsize=12, fontweight='bold')
plt.title('Distribution of Work-Life Balance Scores', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

# Add mean and median lines for reference
mean_val = df['work_life_balance'].mean()
median_val = df['work_life_balance'].median()

plt.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Understanding Skewness
#
# **How to identify skew from a histogram:**
#
# - If **mean > median**: Likely **right-skewed** (tail pulls mean higher)
# - If **mean < median**: Likely **left-skewed** (tail pulls mean lower)
# - If **mean ≈ median**: Likely **roughly symmetric**
#
# The vertical lines in the chart above help you see this relationship visually.
#
# ---

# %% [markdown]
# ## Part 4: Comparing Histograms Across Multiple Columns
#
# Visual comparison helps you understand how different metrics behave.
#
# We'll create a **grid of histograms** to compare all survey metrics side by side.

# %%
# Create a grid of histograms for all numeric columns
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Comparing Distributions Across Survey Metrics', fontsize=16, fontweight='bold', y=0.995)

# Flatten axes for easier iteration
axes = axes.flatten()

colors = ['steelblue', 'seagreen', 'coral', 'mediumpurple', 'gold', 'lightblue']

for idx, column in enumerate(numeric_columns):
    ax = axes[idx]
    
    # Create histogram
    ax.hist(df[column], bins=10, color=colors[idx], edgecolor='black', alpha=0.7)
    
    # Add labels and title
    ax.set_xlabel(column.replace('_', ' ').title(), fontsize=10, fontweight='bold')
    ax.set_ylabel('Frequency', fontsize=10)
    ax.grid(axis='y', alpha=0.3)
    
    # Add mean line
    mean_val = df[column].mean()
    ax.axvline(mean_val, color='red', linestyle='--', linewidth=1.5, alpha=0.7)
    ax.text(mean_val, ax.get_ylim()[1] * 0.9, f'μ={mean_val:.1f}', 
            color='red', fontsize=9, ha='center', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

# Hide the extra subplot
axes[5].axis('off')

plt.tight_layout()
plt.show()

print("\n✅ Comparison grid created successfully")

# %% [markdown]
# ### Comparison Questions
#
# Looking at the grid above:
#
# 1. **Which column has the widest spread?**
# 2. **Which column appears most skewed?**
# 3. **Which columns have similar distributions?**
# 4. **Do any columns show unusual patterns (gaps, multiple peaks)?**
#
# ---

# %% [markdown]
# ## Part 5: Adjusting Bins to Improve Interpretation
#
# The number of **bins** affects how you see the distribution.
#
# - **Too few bins**: Might hide important details
# - **Too many bins**: Might create too much noise
#
# Let's compare the same data with different bin sizes.

# %%
# Compare different bin sizes for satisfaction_score
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Effect of Bin Size on Histogram Interpretation', fontsize=14, fontweight='bold')

bin_sizes = [5, 10, 20]
titles = ['5 Bins (Coarse)', '10 Bins (Moderate)', '20 Bins (Fine)']

for idx, (bins, title) in enumerate(zip(bin_sizes, titles)):
    ax = axes[idx]
    ax.hist(df['satisfaction_score'], bins=bins, color='steelblue', edgecolor='black', alpha=0.7)
    ax.set_xlabel('Satisfaction Score', fontsize=10)
    ax.set_ylabel('Frequency', fontsize=10)
    ax.set_title(title, fontsize=11, fontweight='bold')
    ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print("\n💡 Tip: For most datasets, 10-20 bins provides a good balance.")

# %% [markdown]
# ---
#
# ## Part 6: Detecting Outliers Visually
#
# Histograms help you spot **outliers**: values that are far from the majority of data.
#
# Outliers appear as:
# - Isolated bars far from the main distribution
# - Values in extreme bins with low frequency
#
# Let's create a histogram specifically designed to highlight potential outliers.

# %%
# Analyze avg_engagement for outliers
column = 'avg_engagement'

plt.figure(figsize=(12, 6))

# Create histogram
n, bins, patches = plt.hist(df[column], bins=15, color='lightblue', edgecolor='black', alpha=0.7)

# Highlight potential outlier bins (frequency < 5% of max frequency)
threshold = 0.05 * n.max()
for i, (patch, freq) in enumerate(zip(patches, n)):
    if freq < threshold and freq > 0:
        patch.set_facecolor('red')
        patch.set_alpha(0.8)

plt.xlabel(column.replace('_', ' ').title(), fontsize=12, fontweight='bold')
plt.ylabel('Frequency', fontsize=12, fontweight='bold')
plt.title(f'Distribution of {column.replace("_", " ").title()} with Outlier Highlighting', 
          fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

# Add legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='lightblue', edgecolor='black', label='Normal frequency'),
    Patch(facecolor='red', edgecolor='black', label='Potential outlier region')
]
plt.legend(handles=legend_elements)

plt.tight_layout()
plt.show()

print(f"\n📊 Red bars indicate bins with very low frequency (< {threshold:.1f} observations)")
print("These may contain outliers worth investigating.")

# %% [markdown]
# ---
#
# ## Part 7: Summary Statistics + Histogram = Complete Picture
#
# Histograms are most powerful when combined with summary statistics.
#
# Let's create a comprehensive view.

# %%
# Create a comprehensive analysis for career_growth
column = 'career_growth'

# Calculate statistics
stats = df[column].describe()
mean_val = df[column].mean()
median_val = df[column].median()
mode_val = df[column].mode()[0] if not df[column].mode().empty else None
skew = df[column].skew()

# Create figure with histogram and text box
fig, ax = plt.subplots(figsize=(12, 7))

# Histogram
ax.hist(df[column], bins=10, color='coral', edgecolor='black', alpha=0.7)

ax.set_xlabel(column.replace('_', ' ').title(), fontsize=12, fontweight='bold')
ax.set_ylabel('Frequency', fontsize=12, fontweight='bold')
ax.set_title(f'Complete Distribution Analysis: {column.replace("_", " ").title()}', 
             fontsize=14, fontweight='bold')
ax.grid(axis='y', alpha=0.3)

# Add reference lines
ax.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
ax.axvline(median_val, color='orange', linestyle='--', linewidth=2, label=f'Median: {median_val:.2f}')
ax.legend(loc='upper left')

# Add statistics text box
stats_text = f"""Summary Statistics:
───────────────────
Count:     {stats['count']:.0f}
Mean:      {mean_val:.2f}
Median:    {median_val:.2f}
Mode:      {mode_val}
Std Dev:   {stats['std']:.2f}
Min:       {stats['min']:.0f}
Max:       {stats['max']:.0f}
Range:     {stats['max'] - stats['min']:.0f}
Skewness:  {skew:.2f}

Shape: {'Right-skewed' if skew > 0.25 else 'Left-skewed' if skew < -0.25 else 'Roughly symmetric'}
"""

ax.text(0.98, 0.97, stats_text, transform=ax.transAxes,
        fontsize=10, verticalalignment='top', horizontalalignment='right',
        bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8),
        fontfamily='monospace')

plt.tight_layout()
plt.show()

print("\n✅ Comprehensive distribution analysis complete")

# %% [markdown]
# ---
#
# ## Part 8: Practice Exercise
#
# **Your Turn!**
#
# Create a histogram for the `team_collaboration` column and answer:
#
# 1. What is the shape of the distribution?
# 2. Where are most values located?
# 3. Are there any outliers?
# 4. How does it compare to `satisfaction_score`?
#
# Use the code cells below:

# %%
# Your code here: Create a histogram for team_collaboration

# %%
# Your code here: Compare team_collaboration and satisfaction_score side by side

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# ### What You Learned
#
# 1. ✅ **Histograms visualize distributions** of continuous numeric data
# 2. ✅ **Bins group values** to show frequency patterns
# 3. ✅ **Shape matters**: Normal, skewed, uniform, bimodal all tell different stories
# 4. ✅ **Mean vs. Median** helps identify skewness
# 5. ✅ **Outliers appear** as isolated bars in extreme ranges
# 6. ✅ **Visual + Statistics** = Complete understanding
#
# ### Best Practices
#
# - Always label axes clearly
# - Choose appropriate bin sizes (typically 10-20)
# - Use histograms for **numeric data only**
# - Combine visuals with summary statistics
# - Look for patterns: skew, outliers, gaps, multiple peaks
#
# ### Common Mistakes to Avoid
#
# ❌ Using histograms for categorical data (use bar charts instead)
# ❌ Too many or too few bins
# ❌ Forgetting axis labels
# ❌ Overinterpreting noise in small datasets
# ❌ Ignoring outliers visible in the histogram
#
# ---
#
# ## Next Steps
#
# Now that you can visualize distributions:
#
# - Explore other visualization types (box plots, scatter plots)
# - Practice identifying patterns in different datasets
# - Combine multiple EDA techniques
# - Use insights to guide deeper analysis
#
# **Remember**: Visualization is exploration, not just presentation.
#
# ---
#
# ## Bonus: Using Pandas Built-in Plotting
#
# Pandas DataFrames have a `.plot.hist()` method for quick histograms.

# %%
# Quick histogram using pandas
df['satisfaction_score'].plot.hist(bins=10, color='steelblue', edgecolor='black', alpha=0.7, figsize=(10, 6))

plt.xlabel('Satisfaction Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Quick Histogram Using Pandas', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

plt.show()

print("\n💡 Pandas .plot.hist() is great for quick exploration!")

# %%
# Plot all numeric columns at once
df[numeric_columns].plot.hist(bins=10, alpha=0.7, figsize=(15, 10), subplots=True, layout=(2, 3), 
                               edgecolor='black', legend=False)

plt.suptitle('All Survey Metrics Distributions (Quick Method)', fontsize=14, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

print("\n✅ All histograms created in one line!")

# %% [markdown]
# ---
#
# ## Milestone Complete! 🎉
#
# You now know how to:
#
# - Create histograms for numeric data
# - Interpret distribution shapes and patterns
# - Identify outliers and anomalies visually
# - Compare distributions across multiple columns
# - Combine visualization with statistics
#
# **Next**: Prepare your 2-minute video walkthrough demonstrating histogram creation and interpretation.
#
# ---
